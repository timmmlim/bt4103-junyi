# %% [markdown]
# Ideas:
# - How many questions do we require a student to do before we can get an assessment on his ability?
#
# Modelling Approach:
# - for each student, split observations into train / test data. Earlier observations will be used to train the model to predict the student's performance in the later exercises.
#
# Weaknesses / Assumptions:
# - assumes that students' behaviour is static and will continue beyond the duration of the training data
# - assumes that all topics / chapters are of the same difficulty (eg. calculus is as challenging as linear algebra). we do control for the difficulty of the exercise as tagged in info_content.

# %%
import pandas as pd 
import numpy as np 
import re  
import seaborn as sns 
import matplotlib.pyplot as plt
import os
import datetime as dt

# %%
# %% load data
data_dir = r'C:\Users\Timothy Lim\Desktop\junyi\archive'
info_content = pd.read_csv(os.path.join(data_dir, 'Info_Content.csv'))
info_userdata = pd.read_csv(os.path.join(data_dir, 'Info_UserData.csv'))
log_problem = pd.read_csv(os.path.join(data_dir, 'Log_Problem.csv'))

log_problem['timestamp_TW'] = log_problem['timestamp_TW'].apply(lambda x: dt.datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))
log_problem.sort_values(by='timestamp_TW', ascending=True, inplace=True)
log_problem.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 105021   2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 11669798 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 3768239  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 10163558 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 8372688  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
#
#                                                   ucid  \
# 105021    CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 11669798  CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 3768239   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 10163558  hv7kHCAIdj7thZUmlqz553leG5bFNYgzXmLfB5m4Xvw=
# 8372688   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
#
#                                                   upid  problem_number  \
# 105021    9Ksy3bdm0HTi0D+cdKSBKDQJjo5GNahep91FqHUrpts=               2
# 11669798  /Wgjdl2BsldHZDdXXvzwGimusaMX548lqV2b7PgwXAs=               1
# 3768239   vsGlLPd9C58B8myBoGMGre2pDHjh62eRjsqX57D98fU=               5
# 10163558  h3CI/U4QJd6mjYE5xRH8QEst8lRG7otYIz+q1V6Och4=               5
# 8372688   OSuDd4rDo2muXXwwJRU2DQVHkk6/JOGgNzfzNi4PMJM=               3
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 105021                                  1        True                8
# 11669798                                1        True               10
# 3768239                                 1        True                6
# 10163558                                1        True                5
# 8372688                                 1        True                4
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 105021                    1              0         False          NaN
# 11669798                  1              0         False          NaN
# 3768239                   1              0         False        False
# 10163558                  1              0         False        False
# 8372688                   1              0         False          NaN
#
#          is_upgrade  level
# 105021          NaN      0
# 11669798        NaN      0
# 3768239        True      1
# 10163558       True      1
# 8372688         NaN      0

# %%
info_content.head()
# Out:
#                                            ucid content_pretty_name  \
# 0  odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=       【基礎】怎樣解題：數量關係
# 1  dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=          【基礎】和差問題 1
# 2  C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=          【基礎】雞兔問題 1
# 3  jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=          【基礎】年齡問題 1
# 4  M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=            【基礎】追趕問題
#
#   content_kind difficulty subject learning_stage  \
# 0     Exercise       easy    math     elementary
# 1     Exercise       easy    math     elementary
# 2     Exercise       easy    math     elementary
# 3     Exercise       easy    math     elementary
# 4     Exercise       easy    math     elementary
#
#                                       level1_id  \
# 0  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 1  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 2  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 3  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 4  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
#
#                                       level2_id  \
# 0  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# 1  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# 2  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# 3  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# 4  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
#
#                                       level3_id  \
# 0  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# 1  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# 2  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# 3  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# 4  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
#
#                                       level4_id
# 0  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# 1  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# 2  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# 3  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# 4  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=

# %%
info_content['learning_stage'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
info_content['difficulty'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
info_userdata.head()
# Out:
#                                            uuid gender  points  badges_cnt  \
# 0  Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=    NaN   18300           1
# 1  lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=    NaN    6468           0
# 2  ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=   male    4703           0
# 3  J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=    NaN   15525           1
# 4  qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=    NaN    7945           0
#
#   first_login_date_TW  user_grade user_city  has_teacher_cnt  is_self_coach  \
# 0          2019-01-24           1        kh                0          False
# 1          2019-01-24           1      ntpc                1          False
# 2          2019-01-24           1        tp                0          False
# 3          2019-01-24           2      ntpc                0          False
# 4          2019-01-24           2        km                1          False
#
#    has_student_cnt  belongs_to_class_cnt  has_class_cnt
# 0                0                     0              0
# 1                0                     1              0
# 2                0                     0              0
# 3                0                     0              0
# 4                0                     1              0

# %% [markdown]
# From info_userdata, it wouldn't be appropriate to use most of these columns as it is likely that they are a function of the students' correctness.
#
# Might include things such as user_grade and is_self_coach.

# %% [markdown]
# ### Data Wrangling
#
# - sort the train / test split. for each user, split the observations from log_problem into 70-30 for training and validation data.

# %%
log_problem.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 105021   2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 11669798 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 3768239  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 10163558 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 8372688  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
#
#                                                   ucid  \
# 105021    CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 11669798  CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 3768239   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 10163558  hv7kHCAIdj7thZUmlqz553leG5bFNYgzXmLfB5m4Xvw=
# 8372688   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
#
#                                                   upid  problem_number  \
# 105021    9Ksy3bdm0HTi0D+cdKSBKDQJjo5GNahep91FqHUrpts=               2
# 11669798  /Wgjdl2BsldHZDdXXvzwGimusaMX548lqV2b7PgwXAs=               1
# 3768239   vsGlLPd9C58B8myBoGMGre2pDHjh62eRjsqX57D98fU=               5
# 10163558  h3CI/U4QJd6mjYE5xRH8QEst8lRG7otYIz+q1V6Och4=               5
# 8372688   OSuDd4rDo2muXXwwJRU2DQVHkk6/JOGgNzfzNi4PMJM=               3
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 105021                                  1        True                8
# 11669798                                1        True               10
# 3768239                                 1        True                6
# 10163558                                1        True                5
# 8372688                                 1        True                4
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 105021                    1              0         False          NaN
# 11669798                  1              0         False          NaN
# 3768239                   1              0         False        False
# 10163558                  1              0         False        False
# 8372688                   1              0         False          NaN
#
#          is_upgrade  level
# 105021          NaN      0
# 11669798        NaN      0
# 3768239        True      1
# 10163558       True      1
# 8372688         NaN      0

# %%
# group obserations by uuid, sort by ucid, problem_number and timestamp_TW

user_logs = log_problem.groupby(by='uuid')
user_logs

# %%
# test case

test_userid = 'U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4='
test_user = user_logs.get_group(test_userid).sort_values(by=['timestamp_TW', 'ucid', 'problem_number'], ascending=True)
test_user
# Out:
#                 timestamp_TW                                          uuid  \
# 11669798 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 105021   2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 8372688  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 13311409 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 3768239  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# ...                      ...                                           ...
# 7699120  2019-02-09 18:15:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 14647520 2019-02-09 18:15:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 9214797  2019-02-09 18:15:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 7596291  2019-02-09 18:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 7818659  2019-02-09 18:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
#
#                                                   ucid  \
# 11669798  CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 105021    CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 8372688   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 13311409  CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 3768239   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# ...                                                ...
# 7699120   l2qnFsTkIC5rtckJOSRUU9Fa26UjskhobzBBg0ZOQsM=
# 14647520  l2qnFsTkIC5rtckJOSRUU9Fa26UjskhobzBBg0ZOQsM=
# 9214797   l2qnFsTkIC5rtckJOSRUU9Fa26UjskhobzBBg0ZOQsM=
# 7596291   GhFxv7BoAI++BrgjSP6mVEhEsO33gLRvb66hG7WW6iA=
# 7818659   GhFxv7BoAI++BrgjSP6mVEhEsO33gLRvb66hG7WW6iA=
#
#                                                   upid  problem_number  \
# 11669798  /Wgjdl2BsldHZDdXXvzwGimusaMX548lqV2b7PgwXAs=               1
# 105021    9Ksy3bdm0HTi0D+cdKSBKDQJjo5GNahep91FqHUrpts=               2
# 8372688   OSuDd4rDo2muXXwwJRU2DQVHkk6/JOGgNzfzNi4PMJM=               3
# 13311409  OE6ac/KSBYPUdQIN5KjVZS1QSxWiKqis6mIYB0s6kV4=               4
# 3768239   vsGlLPd9C58B8myBoGMGre2pDHjh62eRjsqX57D98fU=               5
# ...                                                ...             ...
# 7699120   d3xxDFkFvlEa9UW4LRjJueNzOHv0gmhLQYhb3w1bpeE=              24
# 14647520  rp1F9dmqyQZgTFBHfD9u8h3ha8HuuWG0w1X4ef4BoTY=              25
# 9214797   oOak/uloxaP6ii/nCSweplg8TInCDg/QZK22Bub9c8U=              26
# 7596291   QiMXL233FLU1VSqbXsKo1/YWXzwLVn+Yc6QoH7lilqs=               1
# 7818659   dkes91lSeLN0yuQAFLTR0wgmng/z5a0BpjWXJOrq6xM=               2
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 11669798                                1        True               10
# 105021                                  1        True                8
# 8372688                                 1        True                4
# 13311409                                1        True                7
# 3768239                                 1        True                6
# ...                                   ...         ...              ...
# 7699120                                 2        True               10
# 14647520                                2        True               31
# 9214797                                 2       False               45
# 7596291                                 1        True               50
# 7818659                                 1       False              168
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 11669798                  1              0         False          NaN
# 105021                    1              0         False          NaN
# 8372688                   1              0         False          NaN
# 13311409                  1              0         False          NaN
# 3768239                   1              0         False        False
# ...                     ...            ...           ...          ...
# 7699120                   1              0         False          NaN
# 14647520                  1              0         False          NaN
# 9214797                   2              1          True          NaN
# 7596291                   1              0         False          NaN
# 7818659                   2              0         False          NaN
#
#          is_upgrade  level
# 11669798        NaN      0
# 105021          NaN      0
# 8372688         NaN      0
# 13311409        NaN      0
# 3768239        True      1
# ...             ...    ...
# 7699120         NaN      1
# 14647520        NaN      1
# 9214797         NaN      1
# 7596291         NaN      0
# 7818659         NaN      0
#
# [105 rows x 14 columns]

# %%
# check if there are any overlap in content

content_ids = test_user['ucid'].unique()

time_dict = {}
for content_id in content_ids:
    tmp = test_user[test_user['ucid']==content_id]
    
    min_time = tmp['timestamp_TW'].min()
    max_time = tmp['timestamp_TW'].max()
    
    time_dict[content_id] = (min_time, max_time)



for k, v in time_dict.items():
    min_time = v[0]
    max_time = v[1]
    
    for k2, v2 in time_dict.items():
        # check if min time is smaller, and max time is bigger
        if min_time < v2[0] and max_time > v2[1]: 
            print (k, k2)
# Out:
# 1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo= TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo= MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo= U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=

# %%
# check sequence for these

content_ids = ['1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=', 'TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=',
              'MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=', 'U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=']

test_user[test_user['ucid'].isin(content_ids)][['timestamp_TW', 'ucid', 'problem_number']]
# Out:
#                 timestamp_TW                                          ucid  \
# 3582780  2018-08-01 08:00:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
# 6921386  2018-08-01 08:00:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
# 15028525 2018-08-01 08:00:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
# 8480951  2018-08-01 08:00:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
# 6626019  2018-08-01 08:00:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
# 10049056 2018-08-02 07:45:00  TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 11723360 2018-08-02 07:45:00  TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 248029   2018-08-02 08:00:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 353881   2018-08-02 08:00:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 319643   2018-08-02 08:00:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 14933272 2018-08-02 08:00:00  TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 2011940  2018-08-02 08:00:00  TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 120948   2018-08-02 08:00:00  TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 11687211 2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 3678633  2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 8480238  2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 84821    2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 3364817  2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 13076345 2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 13255493 2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 11206698 2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 10049788 2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 320317   2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 11488778 2018-08-02 08:00:00  U6uPrXsMf01kkpbyFTf6NgLBFfypQFIdHmXH8GYZPyw=
# 6625610  2018-08-02 08:15:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 2111589  2018-08-02 08:15:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 8596505  2018-08-02 08:15:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 13076229 2018-08-02 08:15:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 10118308 2018-08-02 08:15:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 1854662  2018-08-02 08:15:00  MefOHEpHMbpSlIglmM0dFv9PLECXPNiRwF5qFmNSncA=
# 10406754 2018-10-21 09:30:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
# 15182249 2018-10-21 09:30:00  1rYu966l6i1cA34mdxukVKusuaDPMwcW6a6WCWe5ZFo=
#
#           problem_number
# 3582780                1
# 6921386                2
# 15028525               3
# 8480951                4
# 6626019                5
# 10049056               1
# 11723360               2
# 248029                 1
# 353881                 2
# 319643                 3
# 14933272               3
# 2011940                4
# 120948                 5
# 11687211               1
# 3678633                2
# 8480238                3
# 84821                  4
# 3364817                5
# 13076345               6
# 13255493               7
# 11206698               8
# 10049788               9
# 320317                10
# 11488778              11
# 6625610                4
# 2111589                5
# 8596505                6
# 13076229               7
# 10118308               8
# 1854662                9
# 10406754               7
# 15182249               8

# %% [markdown]
# Using this as an example, the data is sorted correctly. However, it is not clear which exercises were attempted first on 2018-08-02 08:00:00.
#
# solution -> if same timestamp, then just take all as testing data.

# %%
from sklearn.model_selection import train_test_split
import progressbar

# create X and y data
X_data = {}
y_data = {}
train_size = 0.7

users = user_logs.groups.keys()
bar = progressbar.ProgressBar(maxval=len(users), 
                              widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()    
for i, user in enumerate(users):
    bar.update(i+1)
    user_data = user_logs.get_group(user)
    
    # if only 1 timestamp worth of exercises, skip
    if len(user_data['timestamp_TW'].unique()) == 1:
        continue
    
    # sort values
    user_data.sort_values(by=['timestamp_TW', 'ucid', 'problem_number'], ascending=True, inplace=True)
    
    # split data
    user_train, user_test = train_test_split(user_data, train_size=train_size, shuffle=False)
    
    # check if there is overlap in train and test timestamps
    if user_train['timestamp_TW'].max() == user_test['timestamp_TW'].min():
        idx = user_train['timestamp_TW'].idxmax()
        user_test = user_train.loc[idx:].append(user_test)
        user_train = user_train.loc[:idx][:-1]  # pandas loc slicing is inclusive
        
    # add to dict
    X_data[user] = user_train
    y_data[user] = user_test

bar.finish()
# Out:
# C:\Users\Timothy Lim\Anaconda3\envs\capstone\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [========================================================================] 100%

# %%
print(len(X_data))
print(len(y_data))
# Out:
# 63342
# 63342

# %%
# peek data 

print(X_data[user].shape)
print(y_data[user].shape)

X_data[user]
# Out:
# (101, 14)
# (73, 14)
#                 timestamp_TW                                          uuid  \
# 8818038  2018-10-11 16:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 15221490 2018-10-11 16:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 6705314  2018-10-11 16:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 9031507  2018-10-11 16:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 625467   2018-10-11 16:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# ...                      ...                                           ...
# 5172766  2019-03-11 15:45:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 14250465 2019-03-11 15:45:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 1054399  2019-03-11 15:45:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 14268803 2019-03-25 15:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
# 14087839 2019-03-25 15:15:00  zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=
#
#                                                   ucid  \
# 8818038   4p305X/NqL1Zx9j6BDJEpiQx090kFF3o/LTTGJt5s/E=
# 15221490  4p305X/NqL1Zx9j6BDJEpiQx090kFF3o/LTTGJt5s/E=
# 6705314   4p305X/NqL1Zx9j6BDJEpiQx090kFF3o/LTTGJt5s/E=
# 9031507   4p305X/NqL1Zx9j6BDJEpiQx090kFF3o/LTTGJt5s/E=
# 625467    4p305X/NqL1Zx9j6BDJEpiQx090kFF3o/LTTGJt5s/E=
# ...                                                ...
# 5172766   Iri0Mm69Jhy9dYumaZScJt7B6cHJhAjve5Ii96kP4vc=
# 14250465  Iri0Mm69Jhy9dYumaZScJt7B6cHJhAjve5Ii96kP4vc=
# 1054399   PB+tEauJ6Cu8clF5IHjouv5FqEgH9UDWxbOqE+SBa50=
# 14268803  9OXYxjWigzS5FgP5nZ1y1EAtwQihC19PGhDlRKqK3Pg=
# 14087839  Iri0Mm69Jhy9dYumaZScJt7B6cHJhAjve5Ii96kP4vc=
#
#                                                   upid  problem_number  \
# 8818038   twWapESr+NlCzT7vIOCy1R2DNrEbaLjkjBm4NzJDe5s=               4
# 15221490  OJQd0wnJm6hXWovyHipFGk3Y3xEGmrNhrDlaintgI8Y=               5
# 6705314   WpLmBz31ujLqDg068Bk/74ovvE97d2fDg5S9f8+auhE=               6
# 9031507   c1SMSROr5nekNBrLgNn3KhYFw9FIXE98Qx+vvpeIZes=               7
# 625467    OyxYNZNyji9G6iqmgNAuwEv38Wh53N+IJ9WtRE5hAy8=               8
# ...                                                ...             ...
# 5172766   wtwIkwTxNScsqAZDAVp71cNTcG7VpPtvf7iy7wXI+78=              26
# 14250465  PA7xhLXiW3MxX1FMMWEDh6Nu3hzWY5S1hcszx55Yypc=              27
# 1054399   KoSG7qHimV8YMh8x5fISPIx8b5IRTMoFLh9nph2yXGU=               1
# 14268803  8OlykxhWhqdmoDYEhKD8tSEmLYicz/JYI4slzcjyUpU=              17
# 14087839  ZyOMpsMQKJBz6scnEpYrPCf3COQAr6q8d5+hPk5QUAY=              28
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 8818038                                 1       False               81
# 15221490                                1        True               81
# 6705314                                 1       False               26
# 9031507                                 1        True               18
# 625467                                  1        True               42
# ...                                   ...         ...              ...
# 5172766                                 3        True                3
# 14250465                                5        True                2
# 1054399                                 1        True               79
# 14268803                                1       False                0
# 14087839                                4        True                8
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 8818038                   1              1          True          NaN
# 15221490                  1              0         False          NaN
# 6705314                   1              1          True          NaN
# 9031507                   1              0         False          NaN
# 625467                    1              0         False          NaN
# ...                     ...            ...           ...          ...
# 5172766                   1              0         False          NaN
# 14250465                  1              0         False          NaN
# 1054399                   1              0         False          NaN
# 14268803                  0              3          True          NaN
# 14087839                  1              0         False          NaN
#
#          is_upgrade  level
# 8818038         NaN      0
# 15221490        NaN      0
# 6705314         NaN      0
# 9031507         NaN      0
# 625467          NaN      0
# ...             ...    ...
# 5172766         NaN      1
# 14250465        NaN      1
# 1054399         NaN      0
# 14268803        NaN      3
# 14087839        NaN      1
#
# [101 rows x 14 columns]

# %%
info_userdata.columns
# Out:
# Index(['uuid', 'gender', 'points', 'badges_cnt', 'first_login_date_TW',
#        'user_grade', 'user_city', 'has_teacher_cnt', 'is_self_coach',
#        'has_student_cnt', 'belongs_to_class_cnt', 'has_class_cnt'],
#       dtype='object')

# %%
info_content.columns
# Out:
# Index(['ucid', 'content_pretty_name', 'content_kind', 'difficulty', 'subject',
#        'learning_stage', 'level1_id', 'level2_id', 'level3_id', 'level4_id'],
#       dtype='object')

# %% [markdown]
# For each user, we want to generate the following features:
# - no. of unique ucid attempted
# - no. of repeated upid (will be related to accuracy)
# - avg accuracy, total_sec_taken
# - no. of upgrades (only count True values)
# - no. of downgrades (only count True values)
#
# from info_content:
# - no. of content at each learning stage
# - no. of easy / hard / normal / unset difficulty level problems
#
# from info_userdata:
# - user_grade
# - is_self_coach
#
# please feel free help me think of more features :DDD

# %% [markdown]
# ### Feature Engineering

# %%
info_userdata.columns
# Out:
# Index(['uuid', 'gender', 'points', 'badges_cnt', 'first_login_date_TW',
#        'user_grade', 'user_city', 'has_teacher_cnt', 'is_self_coach',
#        'has_student_cnt', 'belongs_to_class_cnt', 'has_class_cnt'],
#       dtype='object')

# %%
user
# Out:
# 'zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU='

# %%
# for each user, generate the features

def get_ls_counts(value_counts, ls):
    try:
        counts = value_counts.loc[ls]
    except KeyError:
        counts = 0
    return counts
    
def gen_features(data_dict):
    bar = progressbar.ProgressBar(maxval=len(X_data), 
                                  widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])

    bar.start()

    i = 0
    for user, user_data in data_dict.items():
        bar.update(i+1)
        
        # merge with info_content
        user_data = user_data.merge(info_content[['ucid', 'difficulty', 'learning_stage']], how='left', on='ucid')
        
        # from log problem
        n_ucid = len(user_data['ucid'].unique())
        n_repeated_upid = sum(user_data['upid'].value_counts() > 1)
        avg_acc = user_data['is_correct'].mean()
        avg_sec_taken = user_data['total_sec_taken'].mean()
        n_upgrades = user_data['is_upgrade'].sum()
        n_downgrades = user_data['is_downgrade'].sum()
        
        # from info_content
        ls_counts = user_data['learning_stage'].value_counts()
        
        n_elementary = get_ls_counts(ls_counts, 'elementary')
        n_junior = get_ls_counts(ls_counts, 'junior')
        n_senior = get_ls_counts(ls_counts, 'senior')
        
        # from info_userdata
        user_grade = info_userdata.loc[info_userdata['uuid']==user]['user_grade'].values[0]
        user_self_coach = info_userdata.loc[info_userdata['uuid']==user]['is_self_coach'].values[0]
        
        # update the dict
        data_dict[user] = [n_ucid, n_repeated_upid, avg_acc, avg_sec_taken, n_upgrades, n_downgrades,
                           n_elementary, n_junior, n_senior, user_grade, user_self_coach]
        i += 1
        
    bar.finish()

# generate features for input data
gen_features(X_data)
# Out:
# [========================================================================] 100%

# %%
# for y data, just need to get the avg accuracy

for user, user_data in y_data.items():
    avg_acc = user_data['is_correct'].mean()
    y_data[user] = avg_acc

# %%
## create series for students' accuracies
avg_acc_series = pd.Series(y_data)
avg_acc_series.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# create final dataframe for model
final_df = pd.DataFrame.from_dict(X_data, orient='index')
final_df.columns = ['n_ucid', 'n_repeated_upid', 'avg_acc', 'avg_sec_taken', 'n_upgrades',
                   'n_downgrades', 'n_elementary', 'n_junior', 'n_senior', 'user_grade', 'user_self_coach']
final_df.head()
# Out:
#                                               n_ucid  n_repeated_upid  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=       1                0
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=       1                0
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=       4                0
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=      19                2
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=       3               28
#
#                                                avg_acc  avg_sec_taken  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=  0.076923      18.230769
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=  0.500000     121.250000
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=  0.347826      45.086957
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=  0.923077      33.576923
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=  0.658730      24.960317
#
#                                               n_upgrades  n_downgrades  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=           0             0
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=           0             0
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=           0             0
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=          12             0
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=           6             0
#
#                                               n_elementary  n_junior  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=             0        13
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=             4         0
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=            23         0
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=            66        38
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=             0       126
#
#                                               n_senior  user_grade  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=         0           7
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=         0           5
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=         0           6
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=         0           7
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=         0           7
#
#                                               user_self_coach
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=            False
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=            False
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=            False
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=            False
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=            False

# %%
# merge with student avg acc 

avg_acc_series.name = 'avg_acc'
final_df = final_df.merge(avg_acc_series, how='left', left_index=True, right_index=True)
final_df.head()
# Out:
#                                               n_ucid  n_repeated_upid  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=       1                0
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=       1                0
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=       4                0
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=      19                2
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=       3               28
#
#                                               avg_acc_x  avg_sec_taken  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=   0.076923      18.230769
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=   0.500000     121.250000
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=   0.347826      45.086957
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=   0.923077      33.576923
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=   0.658730      24.960317
#
#                                               n_upgrades  n_downgrades  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=           0             0
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=           0             0
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=           0             0
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=          12             0
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=           6             0
#
#                                               n_elementary  n_junior  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=             0        13
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=             4         0
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=            23         0
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=            66        38
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=             0       126
#
#                                               n_senior  user_grade  \
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=         0           7
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=         0           5
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=         0           6
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=         0           7
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=         0           7
#
#                                               user_self_coach  avg_acc_y
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=            False   0.125000
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=            False   0.833333
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=            False   0.833333
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=            False   0.803922
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=            False   0.569231

# %%
# rename columns

final_df.rename(columns={'avg_acc_x': 'curr_avg_acc', 
                        'avg_acc_y': 'future_avg_acc'},
               inplace=True)

# %%
final_df.shape
# Out:
# (63342, 12)

# %%
# bin future avg acc 
final_df['future_avg_acc_binned'] = pd.qcut(final_df['future_avg_acc'], 3, labels=['weak', 'medium', 'strong'])
final_df['future_avg_acc_binned'].value_counts(normalize=True)
# Out:
# medium    0.333507
# weak      0.333333
# strong    0.333160
# Name: future_avg_acc_binned, dtype: float64

# %%
final_df[final_df['future_avg_acc_binned']=='weak']['future_avg_acc'].max()
# Out:
# 0.6630434782608695

# %%
final_df[final_df['future_avg_acc_binned']=='medium']['future_avg_acc'].max()
# Out:
# 0.8260869565217391

# %%
final_df[final_df['future_avg_acc_binned']=='strong']['future_avg_acc'].max()
# Out:
# 1.0

# %% [markdown]
# ### Modelling
#
# XGB!!!!

# %%
train_data, test_data = train_test_split(final_df, test_size=0.3, random_state=12345)
print(train_data.shape)
print(test_data.shape)
# Out:
# (44339, 13)
# (19003, 13)

# %%
train_data.head()
# Out:
#                                               n_ucid  n_repeated_upid  \
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=      22                5
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=       8                6
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=       7                0
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=       1                0
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=      10                0
#
#                                               curr_avg_acc  avg_sec_taken  \
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=      0.909639      30.277108
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=      0.750000      55.468750
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=      0.942857       6.857143
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=      0.000000      32.000000
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=      0.774648      44.281690
#
#                                               n_upgrades  n_downgrades  \
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=          37             0
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=           4             0
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=           6             0
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=           0             0
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=           8             0
#
#                                               n_elementary  n_junior  \
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=           166         0
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=            32         0
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=            35         0
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=             0         1
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=            71         0
#
#                                               n_senior  user_grade  \
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=         0           3
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=         0           5
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=         0           7
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=         0           7
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=         0           6
#
#                                               user_self_coach  future_avg_acc  \
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=            False        0.946667
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=            False        0.833333
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=            False        1.000000
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=            False        1.000000
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=            False        0.777778
#
#                                              future_avg_acc_binned
# /6Y8YBJr1hJnGoercYOIpWZ6fgn0EgEZlaRN4sTOPTA=                strong
# o7dphdTBYWzUArKH7PzA3duPRShLNZ+3bseo69P7QZ8=                strong
# P8JBBGJ+Y6MiustkMgGeuNJvwT5TiQFZRZfJAo5lW9M=                strong
# w+9jIi2FP63gANyhsibs1hnVSn0ZcGlUKnKQgQTTqU8=                strong
# +B2V2ESExjRZ34ldMzUJsOWw+x80fx1gMQg9BXgBupk=                medium

# %%
X_train = train_data.drop(columns=['future_avg_acc_binned', 'future_avg_acc'])
X_test = test_data.drop(columns=['future_avg_acc_binned', 'future_avg_acc'])

y_train = train_data['future_avg_acc_binned']
y_test = test_data['future_avg_acc_binned']

y_train.value_counts(normalize=True)
# Out:
# medium    0.335123
# weak      0.333025
# strong    0.331852
# Name: future_avg_acc_binned, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# strong    0.336210
# weak      0.334053
# medium    0.329737
# Name: future_avg_acc_binned, dtype: float64

# %%
from xgboost import XGBClassifier

# fit with default params
xgb_clf = XGBClassifier(objective='multi:softmax',
                       num_class=3,
                       random_state=12345)

xgb_clf.fit(X_train, y_train, 
            eval_set=[(X_train, y_train), (X_test, y_test)],
            eval_metric=['merror', 'mlogloss'], 
            verbose=True)
# Out:
# [0]	validation_0-merror:0.42437	validation_0-mlogloss:1.01836	validation_1-merror:0.42409	validation_1-mlogloss:1.01895
# [1]	validation_0-merror:0.42297	validation_0-mlogloss:0.96960	validation_1-merror:0.42388	validation_1-mlogloss:0.97139
# [2]	validation_0-merror:0.41956	validation_0-mlogloss:0.93785	validation_1-merror:0.42130	validation_1-mlogloss:0.94103
# [3]	validation_0-merror:0.41909	validation_0-mlogloss:0.91636	validation_1-merror:0.42088	validation_1-mlogloss:0.92111
# [4]	validation_0-merror:0.41852	validation_0-mlogloss:0.90120	validation_1-merror:0.42009	validation_1-mlogloss:0.90776
# [5]	validation_0-merror:0.41706	validation_0-mlogloss:0.89030	validation_1-merror:0.42009	validation_1-mlogloss:0.89884
# [6]	validation_0-merror:0.41616	validation_0-mlogloss:0.88221	validation_1-merror:0.41925	validation_1-mlogloss:0.89260
# [7]	validation_0-merror:0.41557	validation_0-mlogloss:0.87593	validation_1-merror:0.41893	validation_1-mlogloss:0.88827
# [8]	validation_0-merror:0.41388	validation_0-mlogloss:0.87102	validation_1-merror:0.41878	validation_1-mlogloss:0.88557
# [9]	validation_0-merror:0.41293	validation_0-mlogloss:0.86688	validation_1-merror:0.41904	validation_1-mlogloss:0.88346
# [10]	validation_0-merror:0.41284	validation_0-mlogloss:0.86321	validation_1-merror:0.41941	validation_1-mlogloss:0.88213
# [11]	validation_0-merror:0.41165	validation_0-mlogloss:0.86020	validation_1-merror:0.41899	validation_1-mlogloss:0.88096
# [12]	validation_0-merror:0.41102	validation_0-mlogloss:0.85778	validation_1-merror:0.41841	validation_1-mlogloss:0.88023
# [13]	validation_0-merror:0.41034	validation_0-mlogloss:0.85555	validation_1-merror:0.41851	validation_1-mlogloss:0.87962
# [14]	validation_0-merror:0.40932	validation_0-mlogloss:0.85291	validation_1-merror:0.41835	validation_1-mlogloss:0.87932
# [15]	validation_0-merror:0.40840	validation_0-mlogloss:0.85125	validation_1-merror:0.41809	validation_1-mlogloss:0.87913
# [16]	validation_0-merror:0.40808	validation_0-mlogloss:0.84970	validation_1-merror:0.41820	validation_1-mlogloss:0.87885
# [17]	validation_0-merror:0.40716	validation_0-mlogloss:0.84809	validation_1-merror:0.41841	validation_1-mlogloss:0.87860
# [18]	validation_0-merror:0.40682	validation_0-mlogloss:0.84695	validation_1-merror:0.41825	validation_1-mlogloss:0.87866
# [19]	validation_0-merror:0.40632	validation_0-mlogloss:0.84537	validation_1-merror:0.41920	validation_1-mlogloss:0.87850
# [20]	validation_0-merror:0.40585	validation_0-mlogloss:0.84453	validation_1-merror:0.41925	validation_1-mlogloss:0.87852
# [21]	validation_0-merror:0.40535	validation_0-mlogloss:0.84321	validation_1-merror:0.41878	validation_1-mlogloss:0.87846
# [22]	validation_0-merror:0.40432	validation_0-mlogloss:0.84223	validation_1-merror:0.41935	validation_1-mlogloss:0.87852
# [23]	validation_0-merror:0.40398	validation_0-mlogloss:0.84126	validation_1-merror:0.41978	validation_1-mlogloss:0.87862
# [24]	validation_0-merror:0.40321	validation_0-mlogloss:0.83975	validation_1-merror:0.41962	validation_1-mlogloss:0.87875
# [25]	validation_0-merror:0.40208	validation_0-mlogloss:0.83837	validation_1-merror:0.41941	validation_1-mlogloss:0.87881
# [26]	validation_0-merror:0.40107	validation_0-mlogloss:0.83678	validation_1-merror:0.41957	validation_1-mlogloss:0.87885
# [27]	validation_0-merror:0.40075	validation_0-mlogloss:0.83567	validation_1-merror:0.41978	validation_1-mlogloss:0.87891
# [28]	validation_0-merror:0.40005	validation_0-mlogloss:0.83460	validation_1-merror:0.42014	validation_1-mlogloss:0.87896
# [29]	validation_0-merror:0.39895	validation_0-mlogloss:0.83347	validation_1-merror:0.42057	validation_1-mlogloss:0.87907
# [30]	validation_0-merror:0.39852	validation_0-mlogloss:0.83265	validation_1-merror:0.42078	validation_1-mlogloss:0.87923
# [31]	validation_0-merror:0.39802	validation_0-mlogloss:0.83195	validation_1-merror:0.42057	validation_1-mlogloss:0.87938
# [32]	validation_0-merror:0.39710	validation_0-mlogloss:0.83078	validation_1-merror:0.42125	validation_1-mlogloss:0.87957
# [33]	validation_0-merror:0.39626	validation_0-mlogloss:0.82957	validation_1-merror:0.42178	validation_1-mlogloss:0.87974
# [34]	validation_0-merror:0.39503	validation_0-mlogloss:0.82812	validation_1-merror:0.42167	validation_1-mlogloss:0.87980
# [35]	validation_0-merror:0.39397	validation_0-mlogloss:0.82697	validation_1-merror:0.42157	validation_1-mlogloss:0.88003
# [36]	validation_0-merror:0.39378	validation_0-mlogloss:0.82643	validation_1-merror:0.42157	validation_1-mlogloss:0.88011
# [37]	validation_0-merror:0.39320	validation_0-mlogloss:0.82520	validation_1-merror:0.42141	validation_1-mlogloss:0.88006
# [38]	validation_0-merror:0.39279	validation_0-mlogloss:0.82448	validation_1-merror:0.42141	validation_1-mlogloss:0.88005
# [39]	validation_0-merror:0.39257	validation_0-mlogloss:0.82379	validation_1-merror:0.42151	validation_1-mlogloss:0.88010
# [40]	validation_0-merror:0.39248	validation_0-mlogloss:0.82303	validation_1-merror:0.42172	validation_1-mlogloss:0.88024
# [41]	validation_0-merror:0.39218	validation_0-mlogloss:0.82232	validation_1-merror:0.42172	validation_1-mlogloss:0.88031
# [42]	validation_0-merror:0.39148	validation_0-mlogloss:0.82097	validation_1-merror:0.42130	validation_1-mlogloss:0.88039
# [43]	validation_0-merror:0.39051	validation_0-mlogloss:0.81986	validation_1-merror:0.42104	validation_1-mlogloss:0.88054
# [44]	validation_0-merror:0.38957	validation_0-mlogloss:0.81902	validation_1-merror:0.42135	validation_1-mlogloss:0.88066
# [45]	validation_0-merror:0.38923	validation_0-mlogloss:0.81834	validation_1-merror:0.42188	validation_1-mlogloss:0.88081
# [46]	validation_0-merror:0.38833	validation_0-mlogloss:0.81665	validation_1-merror:0.42183	validation_1-mlogloss:0.88077
# [47]	validation_0-merror:0.38763	validation_0-mlogloss:0.81561	validation_1-merror:0.42209	validation_1-mlogloss:0.88096
# [48]	validation_0-merror:0.38686	validation_0-mlogloss:0.81462	validation_1-merror:0.42251	validation_1-mlogloss:0.88096
# [49]	validation_0-merror:0.38612	validation_0-mlogloss:0.81359	validation_1-merror:0.42246	validation_1-mlogloss:0.88104
# [50]	validation_0-merror:0.38501	validation_0-mlogloss:0.81216	validation_1-merror:0.42293	validation_1-mlogloss:0.88133
# [51]	validation_0-merror:0.38395	validation_0-mlogloss:0.81086	validation_1-merror:0.42299	validation_1-mlogloss:0.88151
# [52]	validation_0-merror:0.38377	validation_0-mlogloss:0.81018	validation_1-merror:0.42293	validation_1-mlogloss:0.88160
# [53]	validation_0-merror:0.38343	validation_0-mlogloss:0.80943	validation_1-merror:0.42267	validation_1-mlogloss:0.88154
# [54]	validation_0-merror:0.38273	validation_0-mlogloss:0.80796	validation_1-merror:0.42314	validation_1-mlogloss:0.88164
# [55]	validation_0-merror:0.38224	validation_0-mlogloss:0.80723	validation_1-merror:0.42309	validation_1-mlogloss:0.88171
# [56]	validation_0-merror:0.38172	validation_0-mlogloss:0.80634	validation_1-merror:0.42320	validation_1-mlogloss:0.88174
# [57]	validation_0-merror:0.38115	validation_0-mlogloss:0.80545	validation_1-merror:0.42346	validation_1-mlogloss:0.88183
# [58]	validation_0-merror:0.38016	validation_0-mlogloss:0.80410	validation_1-merror:0.42309	validation_1-mlogloss:0.88184
# [59]	validation_0-merror:0.37922	validation_0-mlogloss:0.80295	validation_1-merror:0.42367	validation_1-mlogloss:0.88181
# [60]	validation_0-merror:0.37843	validation_0-mlogloss:0.80170	validation_1-merror:0.42404	validation_1-mlogloss:0.88196
# [61]	validation_0-merror:0.37764	validation_0-mlogloss:0.80055	validation_1-merror:0.42425	validation_1-mlogloss:0.88216
# [62]	validation_0-merror:0.37676	validation_0-mlogloss:0.79973	validation_1-merror:0.42467	validation_1-mlogloss:0.88253
# [63]	validation_0-merror:0.37651	validation_0-mlogloss:0.79906	validation_1-merror:0.42483	validation_1-mlogloss:0.88270
# [64]	validation_0-merror:0.37610	validation_0-mlogloss:0.79831	validation_1-merror:0.42499	validation_1-mlogloss:0.88281
# [65]	validation_0-merror:0.37558	validation_0-mlogloss:0.79750	validation_1-merror:0.42514	validation_1-mlogloss:0.88297
# [66]	validation_0-merror:0.37470	validation_0-mlogloss:0.79649	validation_1-merror:0.42493	validation_1-mlogloss:0.88313
# [67]	validation_0-merror:0.37373	validation_0-mlogloss:0.79529	validation_1-merror:0.42504	validation_1-mlogloss:0.88322
# [68]	validation_0-merror:0.37331	validation_0-mlogloss:0.79446	validation_1-merror:0.42483	validation_1-mlogloss:0.88336
# [69]	validation_0-merror:0.37254	validation_0-mlogloss:0.79321	validation_1-merror:0.42425	validation_1-mlogloss:0.88351
# [70]	validation_0-merror:0.37198	validation_0-mlogloss:0.79249	validation_1-merror:0.42467	validation_1-mlogloss:0.88361
# [71]	validation_0-merror:0.37150	validation_0-mlogloss:0.79159	validation_1-merror:0.42488	validation_1-mlogloss:0.88367
# [72]	validation_0-merror:0.37071	validation_0-mlogloss:0.79063	validation_1-merror:0.42514	validation_1-mlogloss:0.88371
# [73]	validation_0-merror:0.37051	validation_0-mlogloss:0.79010	validation_1-merror:0.42520	validation_1-mlogloss:0.88380
# [74]	validation_0-merror:0.36974	validation_0-mlogloss:0.78890	validation_1-merror:0.42588	validation_1-mlogloss:0.88409
# [75]	validation_0-merror:0.36897	validation_0-mlogloss:0.78792	validation_1-merror:0.42583	validation_1-mlogloss:0.88411
# [76]	validation_0-merror:0.36830	validation_0-mlogloss:0.78698	validation_1-merror:0.42609	validation_1-mlogloss:0.88429
# [77]	validation_0-merror:0.36805	validation_0-mlogloss:0.78643	validation_1-merror:0.42593	validation_1-mlogloss:0.88446
# [78]	validation_0-merror:0.36758	validation_0-mlogloss:0.78582	validation_1-merror:0.42599	validation_1-mlogloss:0.88447
# [79]	validation_0-merror:0.36685	validation_0-mlogloss:0.78536	validation_1-merror:0.42625	validation_1-mlogloss:0.88448
# [80]	validation_0-merror:0.36609	validation_0-mlogloss:0.78462	validation_1-merror:0.42625	validation_1-mlogloss:0.88473
# [81]	validation_0-merror:0.36532	validation_0-mlogloss:0.78388	validation_1-merror:0.42641	validation_1-mlogloss:0.88482
# [82]	validation_0-merror:0.36521	validation_0-mlogloss:0.78361	validation_1-merror:0.42630	validation_1-mlogloss:0.88478
# [83]	validation_0-merror:0.36483	validation_0-mlogloss:0.78317	validation_1-merror:0.42620	validation_1-mlogloss:0.88496
# [84]	validation_0-merror:0.36415	validation_0-mlogloss:0.78222	validation_1-merror:0.42620	validation_1-mlogloss:0.88510
# [85]	validation_0-merror:0.36331	validation_0-mlogloss:0.78135	validation_1-merror:0.42646	validation_1-mlogloss:0.88527
# [86]	validation_0-merror:0.36282	validation_0-mlogloss:0.78030	validation_1-merror:0.42672	validation_1-mlogloss:0.88550
# [87]	validation_0-merror:0.36192	validation_0-mlogloss:0.77922	validation_1-merror:0.42683	validation_1-mlogloss:0.88574
# [88]	validation_0-merror:0.36146	validation_0-mlogloss:0.77818	validation_1-merror:0.42656	validation_1-mlogloss:0.88592
# [89]	validation_0-merror:0.36047	validation_0-mlogloss:0.77691	validation_1-merror:0.42672	validation_1-mlogloss:0.88591
# [90]	validation_0-merror:0.35962	validation_0-mlogloss:0.77590	validation_1-merror:0.42678	validation_1-mlogloss:0.88614
# [91]	validation_0-merror:0.35925	validation_0-mlogloss:0.77537	validation_1-merror:0.42662	validation_1-mlogloss:0.88630
# [92]	validation_0-merror:0.35910	validation_0-mlogloss:0.77493	validation_1-merror:0.42720	validation_1-mlogloss:0.88645
# [93]	validation_0-merror:0.35865	validation_0-mlogloss:0.77427	validation_1-merror:0.42783	validation_1-mlogloss:0.88655
# [94]	validation_0-merror:0.35813	validation_0-mlogloss:0.77344	validation_1-merror:0.42767	validation_1-mlogloss:0.88664
# [95]	validation_0-merror:0.35770	validation_0-mlogloss:0.77261	validation_1-merror:0.42756	validation_1-mlogloss:0.88668
# [96]	validation_0-merror:0.35691	validation_0-mlogloss:0.77194	validation_1-merror:0.42756	validation_1-mlogloss:0.88680
# [97]	validation_0-merror:0.35610	validation_0-mlogloss:0.77129	validation_1-merror:0.42778	validation_1-mlogloss:0.88686
# [98]	validation_0-merror:0.35538	validation_0-mlogloss:0.77012	validation_1-merror:0.42809	validation_1-mlogloss:0.88696
# [99]	validation_0-merror:0.35495	validation_0-mlogloss:0.76920	validation_1-merror:0.42825	validation_1-mlogloss:0.88726
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_class=3, num_parallel_tree=1,
#               objective='multi:softprob', random_state=12345, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# eval results
results = xgb_clf.evals_result()
epochs = len(results['validation_0']['merror'])
x_axis = range(0, epochs)

# plot log loss
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 7))
ax[0].plot(x_axis, results['validation_0']['mlogloss'], label='Train')
ax[0].plot(x_axis, results['validation_1']['mlogloss'], label='Test')
ax[0].set_ylabel('xgb log loss')
ax[0].legend()


# plot clf error
ax[1].plot(x_axis, results['validation_0']['merror'], label='Train')
ax[1].plot(x_axis, results['validation_1']['merror'], label='Test')
ax[1].set_ylabel('xgb model error')
ax[1].legend()

plt.show()

# %% [markdown]
# Looks like the model is being overfit on the training data.

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix

y_pred = xgb_clf.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
# Out:
# Text(33.0, 0.5, 'Actual')

# %%
from sklearn.metrics import classification_report

clf_report = classification_report(y_test, y_pred, target_names=['weak', 'medium', 'strong'], output_dict=False)
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#         weak       0.51      0.41      0.45      6266
#       medium       0.56      0.68      0.62      6389
#       strong       0.63      0.62      0.63      6348
#
#     accuracy                           0.57     19003
#    macro avg       0.57      0.57      0.57     19003
# weighted avg       0.57      0.57      0.57     19003

# %% [markdown]
# Decent performance in identifying medium/strong students. Recall for weak students is not very high, indicating that the model misses quite a few of these students.
#
# Overall accuracy is not great either.

# %%
# feature importance
feature_names = X_train.columns
importance_scores = zip(feature_names, xgb_clf.feature_importances_)
sorted(importance_scores, key=lambda x: x[1])[::-1]
# Out:
# [('curr_avg_acc', 0.38816264),
#  ('n_ucid', 0.096862264),
#  ('n_upgrades', 0.09616618),
#  ('n_repeated_upid', 0.068714686),
#  ('n_junior', 0.064627826),
#  ('user_grade', 0.062305853),
#  ('n_elementary', 0.056752168),
#  ('avg_sec_taken', 0.053143077),
#  ('user_self_coach', 0.0444183),
#  ('n_downgrades', 0.035877716),
#  ('n_senior', 0.032969177)]

# %% [markdown]
# Most important indicator of future performance appears to be the students' historical performance. No surprises here...
#
# Next steps:
# - play around with the train / test split for each user. 70-30 might be asking too much of the students' data to be collected beforehand.
