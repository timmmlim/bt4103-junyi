# %% [markdown]
# ## Cluster Analysis
#
# ### Create new dataset with relevant features:
# - no. of problems attempted
# - Average time taken for each problem
# - average accuracy
# - Number of times a user upgrades
# - Number of time a user downgrades
# - Average time between each exercise
# - no. of hints used per qns attempted
# - points
# - user grade
# - teacher count
# - student count
# - class count
# - belongs to count
# - badges count

# %%
# Import libraries 
import pandas as pd 
import numpy as np 
import re  
import seaborn as sns 
import matplotlib.pyplot as plt
import os

# %% [raw]
# info_content = pd.read_csv('C:/Users/AdminCOOP/desktop/BT4103/dataset/info_content.csv')
# info_userdata = pd.read_csv('C:/Users/AdminCOOP/desktop/BT4103/dataset/info_UserData.csv')
# log_problem = pd.read_csv('C:/Users/AdminCOOP/desktop/BT4103/dataset/Log_Problem.csv')

# %%
# %% load data
data_dir = r'C:\Users\Timothy Lim\Desktop\junyi\archive'
info_content = pd.read_csv(os.path.join(data_dir, 'Info_Content.csv'))
info_userdata = pd.read_csv(os.path.join(data_dir, 'Info_UserData.csv'))
log_problem = pd.read_csv(os.path.join(data_dir, 'Log_Problem.csv'))

# %%
log_problem
# Out:
#                      timestamp_TW  \
# 0         2019-05-26 21:00:00 UTC
# 1         2019-05-17 16:30:00 UTC
# 2         2019-05-15 19:15:00 UTC
# 3         2019-05-05 14:45:00 UTC
# 4         2019-05-14 16:45:00 UTC
# ...                           ...
# 16217306  2019-04-28 18:30:00 UTC
# 16217307  2019-04-25 19:15:00 UTC
# 16217308  2019-04-25 21:30:00 UTC
# 16217309  2019-04-12 16:30:00 UTC
# 16217310  2019-04-01 20:00:00 UTC
#
#                                                   uuid  \
# 0         FLy+lviglNR5Y1l0Xiijnl6QHySBcpKHJLCtQ6ogm2Q=
# 1         +Gqj2nalc6M9fusyVECTC0AN7UQdDQTXESIuElkDltU=
# 2         6D5QN8j8ng/VR74ES3A0zqAj0bIFFyaKjKEj8ZyXjQ8=
# 3         GgTZuCqZXObthtK6GAwqvlHrTMm5pKHWeezQxL/pcKc=
# 4         JMNKWoU0CkMSzgQ8bCnmCYlD8jEzAVge3lHMYLXKM2g=
# ...                                                ...
# 16217306  OhWXH8C9z/xwoVDoZ8E5HlQcZKQT90HeNxiMoBb8zu4=
# 16217307  EuYrT0f2bBxb1mZgHVsuxgwx3v1M5ObPf6Hxx5JGoYE=
# 16217308  CCM2Y18/BIKVuA1YF76my0pEPuniFUQGDaHB/uRnvak=
# 16217309  kdK8yywPKV0DPbIC7gagzvPyxpC05fA4T9GCBscO2Rk=
# 16217310  sAWxtM6fgTMFGnZ+gRex0UpD5rncOAwRVs0SauTWzfU=
#
#                                                   ucid  \
# 0         KDOmuTrY/IJzDP4kIgIYCBiGyTymsJ8Iy4cDB35WGYg=
# 1         COZ39Wo+uIUO2s7c2VGEHjJf6Vx0xifxVAiaeHtaTdk=
# 2         TwyqyV1uJYlDAX8wX/PtTCVZEBo/APIVfTzzleGkNCQ=
# 3         tBo6ECyT8IlKAM8UhQHWkqv92PRLcSiwuerfC7vNX+w=
# 4         vVpSKAMQbTMvtdERR0ksOeRmmaFt0R210t4Z//0RpPA=
# ...                                                ...
# 16217306  dp0m1kS6Bygoksx9S/gkBqTcWPoglbf1HT3Ma3U3N8U=
# 16217307  WIVV2NtKYatcEnMpVQbIYkGSMd8Q9Xt74y5a+V5bXs0=
# 16217308  ZcwX8fZUrnZDOsvBOPux3Oaf1viIG83MNe5frh0jnQw=
# 16217309  HKqPgUALqZGw984KFqAMeDwDJTi9cNhJ51UXfjzELSg=
# 16217310  5XP5A34EbVYPsNgi2q9tNzuW5fSOenWfbBkAXDGKAfw=
#
#                                                   upid  problem_number  \
# 0         Vbs92l4JmdiWkUEm/iahxnUTaac2oN1IlUtXB7JcfoE=              18
# 1         Ek+pIeHNNoEo0tGEq91eBcBmGgy3+A5RWhpj95zTyHM=               4
# 2         1MBa2f5Qog4JBoAuUfJf0fxeJctdEirAqKgfsg246eI=               9
# 3         kdMy2nG+QVMjPkuaMEWs0yV/sYZVoG1vm7zM0fCy+qk=               2
# 4         jjPR8fmkLSFoCQQYB4g6kI8mgdcK3sKtMirKUvfmZIk=               6
# ...                                                ...             ...
# 16217306  HROyctImDBKuPzjUmVSIohpPweqOuiui22XdmzgKM8I=               7
# 16217307  KbXWuEmsRHIjtQ0iVYmnpnPoDPzKMSRYo7QiezC664s=              24
# 16217308  tfg/S0CdP/aN7ZW8N1hhSJ1Nq/bOFXdtLGkpQYFMzBg=              10
# 16217309  qAAyk/Jf5/muzMzQ9YaWGQPT10enAZctCKNrm3dQ1IY=              40
# 16217310  XdGIwnveMOplh6TxLzeN8TO5SV524bCHxGxeIa3Ixhs=              13
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                       2        True               33
# 1                                       1        True                8
# 2                                       1        True               17
# 3                                       1        True               10
# 4                                       1        True               98
# ...                                   ...         ...              ...
# 16217306                                1        True               11
# 16217307                                2        True               31
# 16217308                                1        True               32
# 16217309                                3        True               22
# 16217310                                1        True               82
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 0                         1              0         False        False
# 1                         1              0         False          NaN
# 2                         1              0         False          NaN
# 3                         1              0         False          NaN
# 4                         1              0         False          NaN
# ...                     ...            ...           ...          ...
# 16217306                  1              0         False        False
# 16217307                  1              0         False        False
# 16217308                  1              0         False          NaN
# 16217309                  1              0         False          NaN
# 16217310                  1              0         False          NaN
#
#          is_upgrade  level
# 0              True      3
# 1               NaN      0
# 2               NaN      0
# 3               NaN      0
# 4               NaN      0
# ...             ...    ...
# 16217306       True      2
# 16217307       True      2
# 16217308        NaN      0
# 16217309        NaN      2
# 16217310        NaN      2
#
# [16217311 rows x 14 columns]

# %% [markdown]
# #### Basic Feature Engineering

# %%
# no. of unique problems attempted
n_problems_attempted = log_problem[['uuid', 'upid']].groupby(by='uuid')['upid'].nunique()
n_problems_attempted
# Out:
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=      5
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=     21
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=     10
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=     41
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=    153
#                                                ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=     26
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=     27
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=    230
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=     23
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=     94
# Name: upid, Length: 72758, dtype: int64

# %%
# no. of unique exercises attempted
n_ex_attempted = log_problem[['uuid', 'ucid']].groupby(by='uuid')['ucid'].nunique()
n_ex_attempted
# Out:
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=     1
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=     1
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=     1
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=     6
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=    25
#                                                 ..
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=     5
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=     4
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=    28
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=     3
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=    12
# Name: ucid, Length: 72758, dtype: int64

# %%
# for each student, what was the avg time they spent per problem? 
avg_time_problem = log_problem.groupby(by='uuid')['total_sec_taken'].mean()
avg_time_problem
# Out:
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=     60.400000
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=     14.758621
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=     89.800000
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=     37.804878
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=     31.890323
#                                                    ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=    130.307692
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=     87.333333
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=     46.907173
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=     10.217391
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=     16.436782
# Name: total_sec_taken, Length: 72758, dtype: float64

# %%
# student accuracy
student_accuracy = log_problem.groupby(by='uuid')['is_correct'].mean()
student_accuracy
# Out:
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=    1.000000
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=    0.103448
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=    0.700000
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=    0.560976
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=    0.883871
#                                                   ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=    0.884615
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=    0.666667
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=    0.552743
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=    0.956522
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=    0.741379
# Name: is_correct, Length: 72758, dtype: float64

# %%
# no. of upgrades and downgrades
n_upgrades = log_problem.groupby(by='uuid')['is_upgrade'].sum()
n_downgrades = log_problem.groupby(by='uuid')['is_downgrade'].sum()

# %%
# no. of hints used per qns attempted
n_hints_per_attempted = log_problem.groupby(by='uuid')['is_hint_used'].mean()
n_hints_per_attempted
# Out:
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=    0.000000
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=    0.724138
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=    0.300000
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=    0.439024
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=    0.032258
#                                                   ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=    0.115385
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=    0.259259
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=    0.295359
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=    0.043478
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=    0.172414
# Name: is_hint_used, Length: 72758, dtype: float64

# %%
import datetime as dt
log_problem['timestamp_TW'] = log_problem['timestamp_TW'].apply(lambda x: dt.datetime.strptime(x[:-4], "%Y-%m-%d %H:%M:%S"))
log_problem.sort_values(by='timestamp_TW', ascending=True, inplace=True)
log_problem.head()
# Out:
#                 timestamp_TW                                          uuid  \
# 105021   2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 11669798 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 3768239  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 10163558 2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 8372688  2018-08-01 07:45:00  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
#
#                                                   ucid  \
# 105021    CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 11669798  CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 3768239   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
# 10163558  hv7kHCAIdj7thZUmlqz553leG5bFNYgzXmLfB5m4Xvw=
# 8372688   CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=
#
#                                                   upid  problem_number  \
# 105021    9Ksy3bdm0HTi0D+cdKSBKDQJjo5GNahep91FqHUrpts=               2
# 11669798  /Wgjdl2BsldHZDdXXvzwGimusaMX548lqV2b7PgwXAs=               1
# 3768239   vsGlLPd9C58B8myBoGMGre2pDHjh62eRjsqX57D98fU=               5
# 10163558  h3CI/U4QJd6mjYE5xRH8QEst8lRG7otYIz+q1V6Och4=               5
# 8372688   OSuDd4rDo2muXXwwJRU2DQVHkk6/JOGgNzfzNi4PMJM=               3
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 105021                                  1        True                8
# 11669798                                1        True               10
# 3768239                                 1        True                6
# 10163558                                1        True                5
# 8372688                                 1        True                4
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 105021                    1              0         False          NaN
# 11669798                  1              0         False          NaN
# 3768239                   1              0         False        False
# 10163558                  1              0         False        False
# 8372688                   1              0         False          NaN
#
#          is_upgrade  level
# 105021          NaN      0
# 11669798        NaN      0
# 3768239        True      1
# 10163558       True      1
# 8372688         NaN      0

# %%
log_problem.tail()
# Out:
#          timestamp_TW                                          uuid  \
# 5351619    2019-08-01  liamj78o0Ae2wnaS0hq7LUfSTsp3xB6HEcffaKBUzGc=
# 8225534    2019-08-01  DndeYzUnQn5RMFK82bE5EUK7UeWFnO3VgT7uAuluqTM=
# 14727695   2019-08-01  t2N6muKWIarXYsUVv/M4rOx/+Qe0Gy9eC0ufuf7vZ0c=
# 13201613   2019-08-01  hCyJTrhgUprNNWpJYKPcyHIxDHnbW91tv0OEM0wXSuI=
# 15112240   2019-08-01  liamj78o0Ae2wnaS0hq7LUfSTsp3xB6HEcffaKBUzGc=
#
#                                                   ucid  \
# 5351619   lG8uYsrQADh32pvOcrvytT25qo4UpZUGkrybb4ycFEs=
# 8225534   Av3E5D+JWfyHjDr2vSsiW200MsgBmim5sLZc4UBQM/0=
# 14727695  GcuG2ukgxXmym9WSnWnlpKVNUFysZ8QfpAgpJMcheMU=
# 13201613  Wk1PobqnhB1FsjjiU84gVNe9j4O6SLWWYfvGb/l6MR4=
# 15112240  zcH7Yl/gFwkU2Mej9UzQgaJL66wIdiMucPZwVyeqHxc=
#
#                                                   upid  problem_number  \
# 5351619   6yQTtifKhIRKCTcjWwYgZEJgiJeKvNzlI9b5pRh5d4s=               6
# 8225534   /ehY6iTAB3z7NB52RLi87aynoVLADwEjle/pIW6WHig=               9
# 14727695  HEFfwmy7pwKhEadwn+17iN+Ik+TEWh7KE6fbKWuf0RU=               6
# 13201613  o1ITX1QcpkBe8d4UjsZH3yUfBC9caKoPTJV7Ls6IqNE=               5
# 15112240  Ms5i+EI/9bpS14wA2YcLHjmfReyVKqfjXuXJe2o9ds8=               1
#
#           exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 5351619                                 1        True               18
# 8225534                                 1        True                7
# 14727695                                1       False              102
# 13201613                                1        True                5
# 15112240                                1        True               31
#
#           total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade  \
# 5351619                   1              0         False        False
# 8225534                   1              0         False          NaN
# 14727695                  2              0         False          NaN
# 13201613                  1              0         False        False
# 15112240                  1              0         False          NaN
#
#          is_upgrade  level
# 5351619        True      1
# 8225534         NaN      1
# 14727695        NaN      1
# 13201613       True      1
# 15112240        NaN      0

# %%
# shift cols down by 1
log_problem['ucid_shifted'] = log_problem.groupby(by='uuid', sort=False)['ucid'].shift(1)
log_problem['timestamp_shifted'] = log_problem.groupby(by='uuid', sort=False)['timestamp_TW'].shift(1)
log_problem[log_problem['uuid']==log_problem['uuid'][100]][['timestamp_TW', 'timestamp_shifted', 'ucid', 'ucid_shifted']]
# Out:
#                 timestamp_TW   timestamp_shifted  \
# 9423058  2019-05-30 16:45:00                 NaT
# 100      2019-05-30 16:45:00 2019-05-30 16:45:00
# 12909679 2019-05-30 16:45:00 2019-05-30 16:45:00
# 3181643  2019-05-30 16:45:00 2019-05-30 16:45:00
# 16105881 2019-05-30 16:45:00 2019-05-30 16:45:00
# ...                      ...                 ...
# 6673029  2019-06-05 13:30:00 2019-06-05 13:15:00
# 4907715  2019-06-05 13:30:00 2019-06-05 13:30:00
# 12714752 2019-06-05 13:30:00 2019-06-05 13:30:00
# 1951229  2019-06-05 13:30:00 2019-06-05 13:30:00
# 12791838 2019-06-05 13:30:00 2019-06-05 13:30:00
#
#                                                   ucid  \
# 9423058   A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# 100       A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# 12909679  Jl92cIZYcCutl8sqyj2VP8UbUigvqBoHBO/R38DK1DU=
# 3181643   A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# 16105881  A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# ...                                                ...
# 6673029   xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 4907715   xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 12714752  xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 1951229   xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 12791838  xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
#
#                                           ucid_shifted
# 9423058                                            NaN
# 100       A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# 12909679  A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# 3181643   Jl92cIZYcCutl8sqyj2VP8UbUigvqBoHBO/R38DK1DU=
# 16105881  A2548sl8hqkIMIGY7mlg/p2NN83cncQx2SgT00lyByk=
# ...                                                ...
# 6673029   z5YJ7GOEyGfxENlfIjBKbMbTzhp3V5TS6Zp62Y/PKPc=
# 4907715   xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 12714752  xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 1951229   xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
# 12791838  xaWHtJt0hf186kbfofLHHt94c0qSZE3L7nvrmIAexws=
#
# [66 rows x 4 columns]

# %%
# keep relevant rows
mask = (log_problem['ucid']!=log_problem['ucid_shifted']) & (log_problem['ucid_shifted'].notna())
relevant_logs = log_problem[mask]

# find time diff
relevant_logs['time_diff'] = (relevant_logs['timestamp_TW'] - relevant_logs['timestamp_shifted']).dt.total_seconds()

# get avg time
avg_time = relevant_logs.groupby(by='uuid')['time_diff'].mean()
avg_time
# Out:
# C:\Users\Timothy Lim\Anaconda3\envs\capstone\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# uuid
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=     33369.230769
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=     52846.601942
# ++KRUQaY4gFsmV7egJVOWqbqbTth/oJBB7yX1HvCSL4=     54818.181818
# ++LzeMQy/8bNUGD2K5Ms/GdiBlQ16ii82xNw3BYtOZE=     35804.651163
# ++N4tZH9IkIqtzD06TVvEK4rjiCHFSSqhCtuDhxJvII=      1687.500000
#                                                     ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=       270.000000
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=       120.000000
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=    206502.352941
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=       120.000000
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=    208050.000000
# Name: time_diff, Length: 62915, dtype: float64

# %%
# check
user = 'zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM='
relevant_logs[relevant_logs['uuid']==user][['timestamp_TW', 'timestamp_shifted', 'time_diff']]
# Out:
#                 timestamp_TW   timestamp_shifted  time_diff
# 9878275  2018-10-18 15:15:00 2018-10-18 14:45:00     1800.0
# 13894993 2018-10-18 15:15:00 2018-10-18 15:15:00        0.0
# 2543842  2018-10-18 15:15:00 2018-10-18 15:15:00        0.0
#
#            timestamp_shifted
# 5787556                  NaT
# 4959781  2018-10-18 14:45:00
# 9878275  2018-10-18 14:45:00
# 13894993 2018-10-18 15:15:00
# 2543842  2018-10-18 15:15:00
# 5033907  2018-10-18 15:15:00
# 662089   2018-10-18 15:15:00
# 15327539 2018-10-18 15:15:00
# 11748199 2018-10-18 15:15:00
# 5328350  2018-10-18 15:15:00
# 3975278  2018-10-18 15:15:00
# 2596327  2018-10-18 15:15:00
# 5507915  2018-10-18 15:15:00
# 2303509  2018-10-18 15:15:00
# 2335811  2018-10-18 15:15:00
# 7130891  2018-10-18 15:15:00
# 5454930  2018-10-18 15:15:00
# 8468832  2018-10-18 15:15:00
# 11938965 2018-10-18 15:15:00
# 921319   2018-10-18 15:15:00
# 12065301 2018-10-18 15:15:00
# 2496263  2018-10-18 15:15:00
# 15470504 2018-10-18 15:15:00

# %%
n_problems_attempted.columns.name = 'asd'
n_problems_attempted
# Out:
# asd                                           upid
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=     5
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=    21
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=    10
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=    41
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=   153
# ...                                            ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=    26
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=    27
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=   230
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=    23
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=    94
#
# [72758 rows x 1 columns]

# %%
# merge everything together
avg_time_problem.name = 'avg_time_per_problem'
student_accuracy.name = 'avg_accuracy'
n_downgrades.name = 'n_downgrades'
n_upgrades.name = 'n_upgrades'
n_hints_per_attempted.name = 'n_hints_per_attempted'
avg_time.name = 'avg_time_btwn_ex'
n_problems_attempted.name = 'n_problems_attempted'
n_ex_attempted.name = 'n_ex_attempted'

clustering_input = pd.concat([n_problems_attempted, n_ex_attempted, avg_time_problem, student_accuracy,
                              n_downgrades, n_upgrades, n_hints_per_attempted, avg_time], axis=1)
clustering_input
# Out:
#                                               n_problems_attempted  \
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=                     5
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=                    21
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=                    10
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=                    41
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=                   153
# ...                                                            ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=        270.000000
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=        120.000000
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=     206502.352941
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=        120.000000
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=     208050.000000
#
# [72758 rows x 8 columns]

# %%
cols_wanted = ['points', 'badges_cnt', 'user_grade', 'has_teacher_cnt', 'has_student_cnt', 'has_class_cnt',
               'belongs_to_class_cnt']

clustering_input = clustering_input.merge(info_userdata[cols_wanted + ['uuid']], left_index=True, right_on='uuid')
clustering_input.set_index('uuid', inplace=True)

# %%
clustering_input.isna().sum()
# Out:
# n_problems_attempted        0
# n_ex_attempted              0
# avg_time_per_problem        0
# avg_accuracy                0
# n_downgrades                0
# n_upgrades                  0
# n_hints_per_attempted       0
# avg_time_btwn_ex         9843
# points                      0
# badges_cnt                  0
# user_grade                  0
# has_teacher_cnt             0
# has_student_cnt             0
# has_class_cnt               0
# belongs_to_class_cnt        0
# dtype: int64

# %%
clustering_input.fillna(0, inplace=True)

# %% [markdown]
# ### Clustering
# * feature scaling / PCA
#     * ideally we want each feature to have a similar scale so that no one feature dominates the clustering algorithm
# * K-means clustering
# * Interpretation of clustering results

# %%
# helper functions
from sklearn.cluster import KMeans

def scale_data(data, scaler):
    scaled_data = pd.DataFrame(scaler.fit_transform(data[data.columns]))
    scaled_data.columns = data.columns
    return scaled_data

def viz_data(data):
    '''
    visualise and check distribution of data
    '''
    
    # infer no. of rows and cols
    nrows = (len(data.columns) // 3) + 1
    ncols = 3
    
    # plot data
    fig, axes = plt.subplots(nrows, ncols, figsize=(22, 20))

    for i, col in enumerate(data.columns):
        target_ax = axes[i // 3, i % 3]
        data[col].plot(kind='hist', ax=target_ax,
                       title=f'distribution of {col}')
    plt.show()

def search_elbow(data):
    clusters = []

    for i in range(1, 11):
        km = KMeans(n_clusters=i).fit(data)
        clusters.append(km.inertia_)

    fig, ax = plt.subplots(figsize=(12, 8))
    sns.lineplot(x=list(range(1, 11)), y=clusters, ax=ax)
    ax.set_title('Searching for Elbow')
    ax.set_xlabel('Clusters')
    ax.set_ylabel('Inertia')

    plt.show()

# %%
# check distribution of original data
viz_data(clustering_input)

# %% [markdown]
# Most of the features are quite skewed. Should look to scale the data

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = MinMaxScaler()  # can try using standard scaler also, not sure abt difference
scaled_clustering_input = scale_data(clustering_input, scaler)
scaled_clustering_input
# Out:
#        n_problems_attempted  n_ex_attempted  avg_time_per_problem  \
# 0                  0.000412        0.000000              0.033556
# 1                  0.002058        0.000000              0.008199
# 2                  0.000926        0.000000              0.049889
# 3                  0.004115        0.006378              0.021003
# 4                  0.015638        0.030612              0.017717
# ...                     ...             ...                   ...
# 72753              0.002572        0.005102              0.072393
# 72754              0.002675        0.003827              0.048519
# 72755              0.023560        0.034439              0.026060
# 72756              0.002263        0.002551              0.005676
# 72757              0.009568        0.014031              0.009132
#
#        avg_accuracy  n_downgrades  n_upgrades  n_hints_per_attempted  \
# 0          1.000000           0.0    0.000367               0.000000
# 1          0.103448           0.0    0.000000               0.724138
# 2          0.700000           0.0    0.000367               0.300000
# 3          0.560976           0.0    0.000734               0.439024
# 4          0.883871           0.0    0.006970               0.032258
# ...             ...           ...         ...                    ...
# 72753      0.884615           0.0    0.001467               0.115385
# 72754      0.666667           0.0    0.001101               0.259259
# 72755      0.552743           0.0    0.006236               0.295359
# 72756      0.956522           0.0    0.001101               0.043478
# 72757      0.741379           0.0    0.004402               0.172414
#
#        avg_time_btwn_ex    points  badges_cnt  user_grade  has_teacher_cnt  \
# 0              0.000000  0.004132    0.001316    0.545455         0.009434
# 1              0.000000  0.000296    0.003947    0.545455         0.009434
# 2              0.000000  0.002355    0.000000    0.363636         0.009434
# 3              0.001201  0.001983    0.000000    0.454545         0.009434
# 4              0.001902  0.010335    0.002632    0.545455         0.009434
# ...                 ...       ...         ...         ...              ...
# 72753          0.000010  0.001853    0.000000    0.727273         0.009434
# 72754          0.000004  0.000926    0.000000    0.272727         0.000000
# 72755          0.007431  0.008244    0.005263    0.181818         0.028302
# 72756          0.000004  0.001975    0.001316    0.363636         0.009434
# 72757          0.007486  0.006931    0.006579    0.545455         0.009434
#
#        has_student_cnt  has_class_cnt  belongs_to_class_cnt
# 0                  0.0            0.0              0.008333
# 1                  0.0            0.0              0.008333
# 2                  0.0            0.0              0.008333
# 3                  0.0            0.0              0.008333
# 4                  0.0            0.0              0.008333
# ...                ...            ...                   ...
# 72753              0.0            0.0              0.008333
# 72754              0.0            0.0              0.000000
# 72755              0.0            0.0              0.033333
# 72756              0.0            0.0              0.000000
# 72757              0.0            0.0              0.000000
#
# [72758 rows x 15 columns]

# %%
# cluster with avg accuracy
search_elbow(scaled_clustering_input)

# %%
# cluster without avg accuracy
search_elbow(scaled_clustering_input.drop('avg_accuracy', axis=1))

# %% [markdown]
# If we include average accuracy, there are possible elbow points at 2 and 4.
# Without including accuracy, seems to only have elbow at 3.

# %%
# fit 4 clusters
km4 = KMeans(n_clusters=4).fit(scaled_clustering_input)

# %%
def twoway_plot(x_data, y_data, labels):
    '''
    scatter plot of x and y data
    '''
    n_labels = len(np.unique(labels))
    plt.figure(figsize=(12, 8))
    sns.scatterplot(x_data, y_data, hue=labels, palette=sns.color_palette('hls', n_labels))
    plt.title(f'KMeans with {n_labels} clusters')
    plt.show()

def violin_plot(data, labels):
    '''
    call to get distribution of clusters for each feature
    '''
    # infer no. of rows
    nrows = (len(data.columns) // 3) + 1
    
    data['labels'] = pd.Series(labels, index=data.index)

    fig, axes = plt.subplots(nrows, 3, figsize=(24, 22))

    for i, col in enumerate(data.drop(columns='labels').columns):
        # print(col)
        target_ax = axes[i // 3, i % 3]
        sns.violinplot(x='labels', y=col, data=data, ax=target_ax)
        target_ax.set_title(f'Labels according to {col}')

    plt.show()

# %%
# 4 clusters
twoway_plot(scaled_clustering_input['n_hints_per_attempted'], scaled_clustering_input['avg_accuracy'],
           km4.labels_)

# %% [markdown]
# avg_accuracy and n_hints_per_attmpted are strongly correlated with each other. Makes sense since I think students will only be shown hints if they had gotten the question wrong the first time.
#
# Cluster 1 and 3 are clearly for weaker students, with average accuracies of less than roughly 60%. Cluster 0 and 2 seem to be more mixed.

# %%
# 4 clusters
twoway_plot(scaled_clustering_input['points'], scaled_clustering_input['avg_accuracy'],
           km4.labels_)

# %% [markdown]
# Points was not useful in clustering, but this may have been due to the outliers. We can try using other preprocessing data transformations (eg. Quantile Transformers)

# %%
# violin plot
violin_plot(scaled_clustering_input, km4.labels_)

# %% [markdown]
# Seems like the clustering is only due to a few features, namely avg_accuracy, n_hints_per_attempted and user_grade
#
# Basically, cluster 0 and 2 are for students with higher avg_accuracy. Clusters 0 and 2 are differentiated by the grade of the students.
#
# We lose a lot of information for the other clusters due to the presence of outliers, which MinMaxScaler does not handle well.
#
# sklearn data preprocessing: https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html

# %%
from sklearn.preprocessing import QuantileTransformer

n_quantiles = 10  # can play around with this
trf = QuantileTransformer(n_quantiles, random_state=12345)
trf_clustering_input = scale_data(clustering_input, trf)
trf_clustering_input
# Out:
#        n_problems_attempted  n_ex_attempted  avg_time_per_problem  \
# 0                  0.088889        0.000000              0.783925
# 1                  0.292929        0.000000              0.098249
# 2                  0.166667        0.000000              0.889603
# 3                  0.437908        0.444444              0.498587
# 4                  0.700000        0.735043              0.390529
# ...                     ...             ...                   ...
# 72753              0.339869        0.388889              0.892218
# 72754              0.346405        0.333333              0.889444
# 72755              0.781032        0.760684              0.640980
# 72756              0.313131        0.277778              0.068018
# 72757              0.604701        0.587302              0.109421
#
#        avg_accuracy  n_downgrades  n_upgrades  n_hints_per_attempted  \
# 0          1.000000           0.0    0.222222               0.000000
# 1          0.024687           0.0    0.000000               0.944828
# 2          0.393241           0.0    0.222222               0.741272
# 3          0.195169           0.0    0.333333               0.883869
# 4          0.807645           0.0    0.755556               0.168459
# ...             ...           ...         ...                    ...
# 72753      0.808984           0.0    0.481481               0.355687
# 72754      0.333333           0.0    0.444444               0.680482
# 72755      0.187913           0.0    0.733333               0.734346
# 72756      0.931898           0.0    0.444444               0.188406
# 72757      0.473501           0.0    0.677778               0.502020
#
#        avg_time_btwn_ex    points  badges_cnt  user_grade  has_teacher_cnt  \
# 0              0.000000  0.452801    0.333333    0.722222         0.611111
# 1              0.000000  0.052265    0.500000    0.722222         0.611111
# 2              0.000000  0.333008    0.000000    0.388889         0.611111
# 3              0.550125  0.292215    0.000000    0.555556         0.611111
# 4              0.620788  0.655176    0.444444    0.722222         0.611111
# ...                 ...       ...         ...         ...              ...
# 72753          0.236660  0.277940    0.000000    0.916667         0.611111
# 72754          0.225152  0.157199    0.000000    0.222222         0.000000
# 72755          0.829242  0.600259    0.555556    0.111111         0.889957
# 72756          0.225152  0.291348    0.333333    0.388889         0.611111
# 72757          0.830214  0.565749    0.592593    0.722222         0.611111
#
#        has_student_cnt  has_class_cnt  belongs_to_class_cnt
# 0                  0.0            0.0              0.611111
# 1                  0.0            0.0              0.611111
# 2                  0.0            0.0              0.611111
# 3                  0.0            0.0              0.611111
# 4                  0.0            0.0              0.611111
# ...                ...            ...                   ...
# 72753              0.0            0.0              0.611111
# 72754              0.0            0.0              0.000000
# 72755              0.0            0.0              0.890772
# 72756              0.0            0.0              0.000000
# 72757              0.0            0.0              0.000000
#
# [72758 rows x 15 columns]

# %%
# check distribution
fig, axes = plt.subplots(5, 3, figsize=(22, 20))

for i, col in enumerate(trf_clustering_input.columns):
    target_ax = axes[i // 3, i % 3]
    trf_clustering_input[col].plot(kind='hist', ax=target_ax,
                                  title=f'distribution of {col}')

plt.show()

# %% [markdown]
# Looks better? Though might have to remove some features (eg. has_student_cnt)

# %%
# searching for elbow
search_elbow(trf_clustering_input)

# %% [markdown]
# RIP

# %%
# try dropping some cols
drop_cols = ['n_downgrades', 'has_student_cnt', 'has_class_cnt']
search_elbow(trf_clustering_input.drop(drop_cols, axis=1))

# %%
from sklearn.preprocessing import PowerTransformer
# Power transforms are a family of parametric, monotonic transformations that are applied to make data more Gaussian-like. 
pwr = PowerTransformer()
pwr_clustering_input = scale_data(clustering_input, pwr)
viz_data(pwr_clustering_input)

# %%
search_elbow(pwr_clustering_input)

# %%
# we can try 5 clusters....? but the inertia is not v low

km5 = KMeans(n_clusters=5).fit(pwr_clustering_input)
np.unique(km5.labels_, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]),
#  array([ 5740, 20263, 29981,  1191, 15583], dtype=int64))

# %%
violin_plot(pwr_clustering_input, km5.labels_)

# %% [markdown]
# Is this better? Is this worse? At least the clustering is no longer dominated by a few features anymore
#
# Consider removing features which appear to be useless in defining the clusters. (eg. has_student_cnt, n_downgrades)

# %%
drop_cols = ['has_student_cnt', 'n_downgrades']
search_elbow(pwr_clustering_input.drop(drop_cols, axis=1))

# %%
# try 5 clusters
km5_v2 = KMeans(n_clusters=5).fit(pwr_clustering_input.drop(drop_cols, axis=1))
print(np.unique(km5_v2.labels_, return_counts=True))

violin_plot(pwr_clustering_input.drop(drop_cols, axis=1), km5_v2.labels_)
# Out:
# (array([0, 1, 2, 3, 4]), array([ 2522, 16930, 21840, 15470, 15996], dtype=int64))

# %% [markdown]
# i'm not really sure if this is better or worse haha

# %%
# generate learning paths (what was the seq. of exercises each student encountered?)

ex_seq = log_problem.groupby(by=['uuid'], sort=False)['ucid'].apply(lambda x: tuple(x.unique()))
ex_seq
# Out:
# uuid
# U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=    (CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=,...
# ZtYcfQTg++4WtnOkIdgI7O4odEyGxOP4ZchUy1ENNIY=    (KpJfQutqPUoUbwWZ5oNFKeVhvKqXZcqL69vsPEHg9jY=,...
# tj/HawoHmjMZJFe3o2B5zeASGbnAuNUtzNd1YrtcHdw=    (TKDAjftSYyI2PNmAkXdInD39P5BcPNa6a+qx0fxm4RA=,...
# AHtLCC16j7YXj6gCouJXMcLe7UapiMEO1DBn5xUfM6Q=    (PGbCr6wCmzlyPoKCBQv8aOM0NW8HVk4PW+IU4iR6GRI=,...
# j/Prqubd0XhHmteIdpCvOcq7IgV4Ib9qLXF1gwNI5ww=    (h327f3+M2F6lvbXTOgg35VC4pac6YD68c7hjS2DPPiA=,...
#                                                                       ...
# saB6CvIM32G0+RDry4wCo5ro6A1kI3fKYaKsjwQc+T4=    (wZCkmlfJ0G2xyiucQ85Ms+DMGXRSg8yhQ+MiwtSHS30=,...
# 90OCKSK8bkx4M+KdLllF8XNzykbJldJtxWaxQRuxPWY=    (XPjtEuV2qgexNe8re/JecZlBLnzABLhXY2kd8BFHlRg=,...
# imiCDl6LZJWvpM7rdQkP1wMTYMFxWC9qTFJsIuFaGhg=      (WkiJbEtcQ/6K9mzb+6b/b9MvUag94v5b3NTx6TRIcn8=,)
# 0Zo0lVHE8Y33fjFhq9XiO/C1ha5rwl9sQ5Hd8h5dEjw=    (dVKfHzCsi1dOBhd343bsUNF4dowsiANnvRBkWqToitg=,...
# PeAJ/aTTLSnfsL0/ThfImpcf0AKPlIoAXHMZIixaHPw=      (tOR47i7wGbuHkGxkhX9tHItMHHuJtAttsvHDOjDRVOw=,)
# Name: ucid, Length: 72758, dtype: object

# %%
# check
user = ex_seq.index[0]
result = ex_seq.loc[user]

all(log_problem[log_problem['uuid']==user]['ucid'].drop_duplicates().values == result)
# Out:
# True

# %%
pwr_clustering_input.index = clustering_input.index
pwr_clustering_input['ex_seq'] = ex_seq

# check
assert all(pwr_clustering_input.loc[user, 'ex_seq']==log_problem[log_problem['uuid']==user]['ucid'].drop_duplicates().values)

pwr_clustering_input
# Out:
#                                               n_problems_attempted  \
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=             -1.410654
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=             -0.590123
# ++E4TrlDYvGtPBg1edhkLXLEEbnfiAgAamPQ33vpW8M=             -1.026137
# ++G4mkLfs4WDYhc1Ga+3G+/oqSniQQvLBm7SBQ3V39Y=             -0.186902
# ++GobOSWqrsaxoRg1bMN+T6biIJcgBXwuOH/ddq3DiU=              0.613114
# ...                                                            ...
# zztwLsjf44Uzumou84qh04wObpugkIllLCIp/mgoMu8=             -0.462051
# zzueVRV14tXIEgW4ixiqmtPNaFYz4MIifbMM/H2tmqA=             -0.439343
# zzujjvdKzb4wL8cFKdF3Of5gg2XHzIDQCZ2TfaYpSNs=              0.860017
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=             -0.535667
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=              0.317245
#
#                                               n_ex_attempted  \
# uuid
# ++5bdNp/LZvGenJ8Brp4n2SfS9d4pu4qA7cF7FQW7hk=       -1.508296
# ++9EkR6syMGk44XpyhOj40cg9xiXwCLS/TwEy+ujrL0=       -1.508296
# zzvvUOwcSXXTXd8xoyimNcm2DjeVPLmZAI19WKfhSAM=  (CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=,...
# zzyukk9LNl7j/9xxgZj6roQBbGn1MjSPTCgc0r5sXpU=  (4p305X/NqL1Zx9j6BDJEpiQx090kFF3o/LTTGJt5s/E=,...
#
# [72758 rows x 17 columns]

# %%
# no. of unique exercise sequences
ex_seq.nunique()
# Out:
# 58226

# %%
# most popular courses for each cluster
top_n = 5
count_seq = pwr_clustering_input.groupby(by=['labels', 'ex_seq']).size().reset_index(name='count')
most_pop_by_label = count_seq.sort_values(by=['labels', 'count'], ascending=False).groupby(by='labels').head(top_n)

most_pop_by_label
# Out:
#        labels                                             ex_seq  count
# 58966       4    (tOR47i7wGbuHkGxkhX9tHItMHHuJtAttsvHDOjDRVOw=,)     77
# 57497       4    (jyw4UBYsVqQ8IeYXUywTKN8TEZjJgYNuhb6JBTBoidg=,)     66
# 52814       4    (JcrFXI7wzq/14kZRPCdix3feq0/yQh1gHU06bGQwNBE=,)     59
# 49829       4    (+cLbiKkV7+VhNPr7OGG3B3kPpZ8er0mvFvqPbM/gm+E=,)     57
# 59847       4    (zX5HAUpRYC4F7YPNs5tUeBqVi++rEmPUfsAtHpoZmEQ=,)     57
# 48594       3    (+cLbiKkV7+VhNPr7OGG3B3kPpZ8er0mvFvqPbM/gm+E=,)      2
# 48775       3    (CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=,)      2
# 48908       3    (Iq4bn747ApUwO7SvDR8vvfjBWGvDxAyBTsce0dN3Q1w=,)      2
# 48949       3    (JcrFXI7wzq/14kZRPCdix3feq0/yQh1gHU06bGQwNBE=,)      2
# 49173       3    (T2hI5mqqogezvse00UeJHgHc3DDK1vrGyyn7Z6IIpsM=,)      2
# 48224       2  (zX5HAUpRYC4F7YPNs5tUeBqVi++rEmPUfsAtHpoZmEQ=,...     10
# 20058       2  (42SFjQ+xu0j97j13pHv3KG8Ha68fBYaZmYs3641qwho=,...      7
# 45748       2  (tOR47i7wGbuHkGxkhX9tHItMHHuJtAttsvHDOjDRVOw=,...      7
# 48279       2  (zX5HAUpRYC4F7YPNs5tUeBqVi++rEmPUfsAtHpoZmEQ=,...      7
# 29958       2  (OVwmRGTNCS+hBkvFYDawSwdperfo46ooCVV/tBEfd84=,...      6
# 7996        1    (CPI+5YCeEmhqdk6znJeii6jJUNl1QWGEvwCUJ6uLflg=,)    320
# 17521       1    (tOR47i7wGbuHkGxkhX9tHItMHHuJtAttsvHDOjDRVOw=,)    239
# 17549       1  (tOR47i7wGbuHkGxkhX9tHItMHHuJtAttsvHDOjDRVOw=,...    154
# 18688       1    (zX5HAUpRYC4F7YPNs5tUeBqVi++rEmPUfsAtHpoZmEQ=,)    122
# 11234       1    (PqQyQvOjvvozBCtlR/0pL8uxhe0K63IPiKYCi1tDG1o=,)    118
# 314         0  (5KQ7wVusODIGXeR77YTjuxxWFJmiYmgbaEGhEYj+nLA=,...      2
# 1262        0  (HDHAipSsrFpMgCVqD8wYT4JhziGVSgjG2rkkL3dKY/g=,...      2
# 3165        0  (aMy+V/IgYkfzzxp0JhGeJIW3f3X4rBOZf/UgsI2IX/4=,...      2
# 0           0  (+DlgHAr1GtoQgtGqwoen6pt4/ayVRO+rMaCVZ7jGCHE=,...      1
# 1           0  (+Lgj0Me9/8gtiruGKq8KxemAD15kU4yCfb6nteNDWjw=,...      1

# %%
info_content.shape
# Out:
# (1330, 10)

# %%
log_problem['ucid'].nunique()
# Out:
# 1326

# %%
# size of each cluster
pwr_clustering_input['labels'].value_counts().plot(kind='bar', title='no. of students in each cluster')
# Out:
# <AxesSubplot:title={'center':'no. of students in each cluster'}>

# %% [markdown]
# Results sort of interesting??? A larger proportion of cluster 0 and cluster 3 students take a similar course sequence. There are more students in cluster 4, yet they don't necessarily all take the same sequence of courses.
#
# In earlier analysis, cluster 4 represents students with lower average accuracy while cluster 1 have higher accuracy.
#
# cluster 2 students have a seemingly mediocre performance in terms of average accuracy.

# %% [markdown]
# #### Interpretation of Results with PCA
#
# idea:
# - within each cluster, identify the dimensions which have the most variance

# %%
pwr_clustering_input.columns
# Out:
# Index(['n_problems_attempted', 'n_ex_attempted', 'avg_time_per_problem',
#        'avg_accuracy', 'n_downgrades', 'n_upgrades', 'n_hints_per_attempted',
#        'avg_time_btwn_ex', 'points', 'badges_cnt', 'user_grade',
#        'has_teacher_cnt', 'has_student_cnt', 'has_class_cnt',
#        'belongs_to_class_cnt', 'labels', 'ex_seq'],
#       dtype='object')

# %%
from sklearn.decomposition import PCA

def cluster_pca(labelled_data, cluster, n_components=None, return_pca=False):
    '''
    helper function to perform PCA on selected cluster
    
    idea: within each cluster, decompose the data to identify dimensions in which there is the most variance
    '''
    # select data from cluster
    cluster_mask = labelled_data['labels']==cluster
    cluster_data = labelled_data[cluster_mask]
    
    if 'labels' in cluster_data.columns:
        cluster_data.drop(columns='labels', axis=1, inplace=True)
    
    if 'ex_seq' in cluster_data.columns:
        cluster_data.drop(columns='ex_seq', axis=1, inplace=True)

    # fit PCA
    pca = PCA(n_components, random_state=12345)
    pca.fit(cluster_data)
    
    # plot results
    fig, ax = plt.subplots(figsize=(14, 8))
    components = pd.DataFrame(pca.components_,
                             columns=cluster_data.columns)
    components.plot(kind='bar', ax=ax)
    ax.set_ylabel('Feature Weights')
    ax.set_xticklabels(components.index)
    plt.axhline(0, linestyle='--', color='black')
    
    for i, ev in enumerate(pca.explained_variance_ratio_): 
        ax.text(i-0.4, ax.get_ylim()[1]+0.05, '%.4f'%(ev))

    plt.legend(title='features', bbox_to_anchor=(1.05, 1))
    plt.tight_layout()
    
    if return_pca:
        return pca

cluster_pca(pwr_clustering_input, cluster=0, n_components=5)

# %% [markdown]
# The above plot tells us for a given cluster, how much each of the input features contributes to variance in the Xth principal component.
#
# For example, the 1st component shows that most of the variance can be explained by belongs_to_class_cnt (or is it n_downgrades?)
#
# This method can be used to compare variance across clusters
